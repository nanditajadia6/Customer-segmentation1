# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
df =pd.read_csv(r"C:\Users\nandita\MINI project\CSV Files\Hand Gestures\wrist extension.csv")
df.head()
# Out:
#     time  channel1  channel2  channel3  channel4  channel5  channel6  \
# 0  18614  -0.00014  -0.00029  -0.00036  -0.00047  -0.00075  -0.00066
# 1  18615  -0.00014  -0.00029  -0.00036  -0.00047  -0.00075  -0.00066
# 2  18616  -0.00014  -0.00029  -0.00036  -0.00047  -0.00075  -0.00066
# 3  18617  -0.00014  -0.00029  -0.00036  -0.00047  -0.00075  -0.00066
# 4  18618  -0.00014  -0.00029  -0.00036  -0.00047  -0.00075  -0.00066
#
#    channel7  channel8  class  label
# 0   -0.0001   -0.0001      4      1
# 1   -0.0001   -0.0001      4      1
# 2   -0.0001   -0.0001      4      1
# 3   -0.0001   -0.0001      4      1
# 4   -0.0001   -0.0001      4      1

# %%
start_col = 1 # start at the second column (index 1)
end_col = 9

fig, ax = plt.subplots(8, 1, figsize=(20, 40), sharex=True)
for i, col in enumerate(df.columns[start_col:end_col]):
    ax[i].plot(df[col])
    ax[i].set_ylabel(col)
ax[7].set_xlabel('EMG Signals')
plt.show()

# %%
rms =(np.mean(df.iloc[:, 1:9]**2, axis=0))
rms1 = np.sqrt(rms)
rms1
# Out:
# channel1    0.000049
# channel2    0.000072
# channel3    0.000100
# channel4    0.000218
# channel5    0.000343
# channel6    0.000249
# channel7    0.000103
# channel8    0.000083
# dtype: float64

# %%
df = pd.read_csv(r"C:\Users\nandita\MINI project\CSV Files\Hand Gestures\wrist extension.csv", header=0, skiprows=[1])

def zero_crossings(x):
    return np.where(np.diff(np.sign(x)))[0]

# plot the EMG signals for each channel
start_col = 1 # start at the second column (index 1)
end_col = 9

fig, ax = plt.subplots(8, 1, figsize=(20, 40), sharex=True)
for i, col in enumerate(df.columns[start_col:end_col]):
    ax[i].plot(df[col])
    ax[i].set_ylabel(col)

    # find the positive zero crossing points and plot them as red dots
    zero_crossings_col = zero_crossings(df[col])
    ax[i].plot(zero_crossings_col, df[col][zero_crossings_col], 'ro')

# set the x-axis label and show the plot
ax[7].set_xlabel('Sample')
plt.show()
