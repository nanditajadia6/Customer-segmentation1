# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
df =pd.read_csv(r"C:\Users\nandita\MINI project\CSV Files\Hand Gestures\ulnar deviations.csv")
df.head()
# Out:
#     time  channel1  channel2  channel3  channel4  channel5  channel6  \
# 0  29926   0.00005  -0.00013   0.00004  -0.00005   0.00005   0.00009
# 1  29927   0.00009  -0.00014  -0.00019  -0.00029  -0.00050  -0.00038
# 2  29929  -0.00032  -0.00025  -0.00006   0.00013   0.00028   0.00011
# 3  29930   0.00026   0.00003  -0.00004  -0.00006  -0.00011  -0.00013
# 4  29931   0.00026   0.00003  -0.00004  -0.00006  -0.00011  -0.00013
#
#    channel7  channel8  class  label
# 0   0.00011   0.00040      6      1
# 1   0.00003   0.00014      6      1
# 2  -0.00020   0.00009      6      1
# 3  -0.00015   0.00006      6      1
# 4  -0.00015   0.00006      6      1

# %%
start_col = 1 # start at the second column (index 1)
end_col = 9

fig, ax = plt.subplots(8, 1, figsize=(20, 40), sharex=True)
for i, col in enumerate(df.columns[start_col:end_col]):
    ax[i].plot(df[col])
    ax[i].set_ylabel(col)
ax[7].set_xlabel('EMG Signals')
plt.show()

# %%
rms =(np.mean(df.iloc[:, 1:9]**2, axis=0))
rms1 = np.sqrt(rms)
rms1
# Out:
# channel1    0.000247
# channel2    0.000194
# channel3    0.000071
# channel4    0.000081
# channel5    0.000157
# channel6    0.000126
# channel7    0.000165
# channel8    0.000235
# dtype: float64

# %%
df = pd.read_csv(r"C:\Users\nandita\MINI project\CSV Files\Hand Gestures\ulnar deviations.csv", header=0, skiprows=[1])

def zero_crossings(x):
    return np.where(np.diff(np.sign(x)))[0]

# plot the EMG signals for each channel
start_col = 1 # start at the second column (index 1)
end_col = 9

fig, ax = plt.subplots(8, 1, figsize=(20, 40), sharex=True)
for i, col in enumerate(df.columns[start_col:end_col]):
    ax[i].plot(df[col])
    ax[i].set_ylabel(col)

    # find the positive zero crossing points and plot them as red dots
    zero_crossings_col = zero_crossings(df[col])
    ax[i].plot(zero_crossings_col, df[col][zero_crossings_col], 'ro')

# set the x-axis label and show the plot
ax[7].set_xlabel('Sample')
plt.show()
