# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
df =pd.read_csv(r"C:\Users\nandita\MINI project\CSV Files\Hand Gestures\hand clenched in a fist.csv")
df.head()
# Out:
#    time  channel1  channel2  channel3  channel4  channel5  channel6  channel7  \
# 0  6662  -0.00011  -0.00002  -0.00007  -0.00008  -0.00016  -0.00018  -0.00036
# 1  6663   0.00014   0.00001   0.00021   0.00016   0.00012  -0.00025  -0.00021
# 2  6664   0.00014   0.00001   0.00021   0.00016   0.00012  -0.00025  -0.00021
# 3  6665   0.00014   0.00001   0.00021   0.00016   0.00012  -0.00025  -0.00021
# 4  6666   0.00014   0.00001   0.00021   0.00016   0.00012  -0.00025  -0.00021
#
#    channel8  class  label
# 0  -0.00001      2      1
# 1   0.00006      2      1
# 2   0.00006      2      1
# 3   0.00006      2      1
# 4   0.00006      2      1

# %%
v=df.time
start_col = 1 # start at the second column (index 1)
end_col = 9

fig, ax = plt.subplots(8, 1, figsize=(20, 40), sharex=True)
for i, col in enumerate(df.columns[start_col:end_col]):
    ax[i].plot(v,df[col])
    ax[i].set_ylabel(col)
ax[7].set_xlabel('EMG Signals')
plt.show()

# %%
# Calculate RMS value of EMG signals
rms =(np.mean(df.iloc[:, 1:9]**2, axis=0))
rms1 = np.sqrt(rms)
rms1
# Out:
# channel1    0.000284
# channel2    0.000147
# channel3    0.000219
# channel4    0.000155
# channel5    0.000166
# channel6    0.000245
# channel7    0.000270
# channel8    0.000183
# dtype: float64

# %%
abs_emg_signals = np.abs(df.iloc[:, 1:9])

# Plot EMG signals
fig, axs = plt.subplots(8, 1, figsize=(20, 40), sharex=True)

for i, col in enumerate(df.columns[1:9]):
    axs[i].plot(abs_emg_signals[col])
    axs[i].set_ylabel(col)
    
plt.xlabel("Sample")
plt.show()

# %%
def zero_crossings(x):
   
    return np.where(np.diff(np.sign(x)))[0]
# plot the EMG signals for each channel
start_col = 1 # start at the second column (index 1)
end_col = 9

fig, ax = plt.subplots(8, 1, figsize=(20, 40), sharex=True)
for i, col in enumerate(df.columns[start_col:end_col]):
    ax[i].plot(df[col])
    ax[i].set_ylabel(col)

    
    # find the zero crossing points and plot them as red dots
    zero_crossings_col = zero_crossings(df[col])
    ax[i].plot(zero_crossings_col, df[col][zero_crossings_col], 'ro')

# set the x-axis label and show the plot
ax[7].set_xlabel('Sample')
plt.show()
